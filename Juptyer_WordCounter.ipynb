# %%
import json

with open('/PATHNAME_HERE.ipynb') as json_file:
    data = json.load(json_file)

print(data)
# Out:
# {'cells': [{'cell_type': 'markdown', 'id': 'dec1eb8c', 'metadata': {}, 'source': ['# Assessment 2:']}, {'cell_type': 'markdown', 'id': '526e29db', 'metadata': {}, 'source': ['## Part A — Data Analysis, Preparation and Verification Plan']}, {'cell_type': 'markdown', 'id': 'd39bcf2b', 'metadata': {}, 'source': ['#### Objective:\n', 'The purpose of this report is to determine Darwin city property values of a 3x2 house.\n', '\n', '#### Target:\n', 'Identify the top Darwin suburbs to invest for the period 2025-2030.']}, {'cell_type': 'markdown', 'id': '3670d70c', 'metadata': {}, 'source': ['### Data Sources']}, {'cell_type': 'markdown', 'id': 'ff370f99', 'metadata': {}, 'source': ['This report draws on key house prices predictors to determine the best suburbs to invest in 3x2 houses from 2025 to 2030. The analysis will draw on housing specific data from crime numbers, employment trends, and public transport links to identify the top zipcodes for your investment. By looking at these tried-and-true indicators for influencing property dynamics we aim to map out where house values are most likely to climb.\n', '\n', '#### 1. Housing Data\n', 'Will be sourced from publicly available secondary data on Kaggle. It contains 2022 property information from Darwin, Australia, focusing on location, property type, and listing price. \n', 'This data serves as the foundational dataset to analyse the market and contains baseline property values, location by zipcodes and property types.\n', '\n', '#### 2. Crime\n', 'Regional primary data is provided by the Northern Territory government open data portal. It contains the number of offences recorded by Northern Territory police by region each month. The information of interest is 12 datasets for 2022 and total number or offences recorded by zipcode. \n', 'Understanding crime rates is crucial as they can significantly influence property values (Kavaarpuo et al. 2024). Lower crime rates are typically associated with higher property values. Analyzing this data will allow us to predict which zipcodes are likely to see an appreciation in property values due to safer environments.\n', '\n', '#### 3. Employment Rates\n', 'This publically availble primary data from Australian Bureau of Statistics Census. Information about employment rates and types by Darwin suburbs will be included in the study.\n', 'Employment rates are a strong indicator of economic health in a region. Higher employment rates can lead to increased demand for housing, driving up property values (Australian Senate, n.d.). This data will help correlate economic activity with property prices, assisting in identifying areas with growth potential.\n', '\n', '#### 4. Public Transport\n', 'Can also be sourced from the Northern Territory government open data portal. Information on the number of bus routes in each zipcode will be used.\n', 'Darwin public transport is limited to the bus network. Access to this resource may be in demand (Realestate.com.au, 2022). By analysing this data we may help highlight areas likely to see property value appreciation linked to better public transport facilities.\n']}, {'cell_type': 'markdown', 'id': 'ebb3f099', 'metadata': {}, 'source': ['#### Data collection issues:\n', '\n', 'We plan to address the challenges of merging datasets by carefully filling in information gaps, ensuring all data points align correctly, and handling any private information sensitively. This will involve:\n', '\n', '*Missing Data*\n', '\n', "To ensure comprehensive analysis, the main housing dataset will be populated with information from crime, employment, and transport datasets. For the crime datasets, obtaining zipcodes for each entry from the NT government is crucial for precise location identification. Similarly, in the transport dataset, mapping suburbs to Darwin zipcodes and subsequently imputing these counts into the main dataset will ensure public transport availabliity is included. Finallly, to incorporate economic indicators, an ...

# %%
wordCount = 0
for each in data['cells']:
    cellType = each['cell_type']
    if cellType == "markdown":
        content = each['source']
        for line in content:
            temp = [word for word in line.split() if "#" not in word] # we might need to filter for more markdown keywords here
            wordCount = wordCount + len(temp)
            
print(wordCount)
# Out:
# 2237
